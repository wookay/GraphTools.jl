# %%
using GraphTools;
# Out:
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/Graphs.ji for module Graphs.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/DataStructures.ji for module DataStructures.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/Cairo.ji for module Cairo.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/FixedPointNumbers.ji for module FixedPointNumbers.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/ColorTypes.ji for module ColorTypes.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/Colors.ji for module Colors.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/Reexport.ji for module Reexport.
# INFO: Recompiling stale cache file /Users/wookyoung/.julia/lib/v0.5/Graphics.ji for module Graphics.

# %%
draw( @graph "A" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfce19950,false)

# %%
draw( @graph "A" - "B" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfd080140,false)

# %%
draw( @graph "A" -> "B" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfd041570,false)

# %%
draw( @graph "A" 50-> "B" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfd0b5bd0,false)

# %%
draw( @graph "A" 50-> "B" -> "C" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfd0740e0,false)

# %%
draw( @graph "A" -> "B" -> "C" -> "A" )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfd16dc30,false)

# %%
draw( (@graph "A" -> "B") + (@graph "A" -> "C") + (@graph "D") )
# Out:
# GraphViz.Graph(Ptr{Void} @0x00007ffdfcf8a2e0,false)
